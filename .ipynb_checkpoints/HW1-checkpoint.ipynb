# %% [markdown]
# ### Задание 1
# ### Площадь и периметр квадрата
#
# Посчитайте площадь и периметр квадрата, сторона которого равна 6.

# %%
a = 6  # Сторона квадрата

perimeter = a*4  # Расчёт периметра
area = a**2  # Расчёт площади

print('Периметр:', perimeter)
print('Площадь:', area)
# Out:
# Периметр: 24
# Площадь: 36

# %% [markdown]
# ### Задание 2
# ### Приложение для финансового планирования
#
# Создайте код, который можно использовать для планирования личных финансов.
# При создании программы опирайтесь на данные, описанные ниже.
# Сколько денег тратит пользователь на ипотеку в год и сколько он накопит за год (накопления составят остаток от заработанной платы после оплаты ипотеки и расходов на жизнь), если:
# - заработная плата в месяц = 100 000 руб.,
# - расходы на ипотеку = 30% от заработной платы,
# - расходы на жизнь = 50% от заработной платы?

# %%
# Задайте первоначальные значения

salary = 100000         # Заработная плата
percent_mortgage = 30   # Ипотека
percent_life = 50       # На жизнь

# Напишите свой код здесь
mortgage = 12*salary*percent_mortgage/100                       # в деньгах на ипотеку за 12 месяцев
result = 12*salary*(100 - percent_life - percent_mortgage)/100  # в деньгах на жизнь за 12 месяцев

print('Ипотека:', mortgage)
print('Накопления:', result)
# Out:
# Ипотека: 360000.0
# Накопления: 240000.0

# %% [markdown]
# ### Задание 3
#
# ### Проверка возраста
#
# Напишите программу, которая проверяет возраст пользователя (переменная age) и выводит сообщение «Доступ разрешён», если возраст больше или равен 18, и «Доступ запрещён», если возраст меньше 18.
# В тренажере будет с функциями, а тут - без.

# %%
age = (input ("Введите Ваш возраст"))
try:
    if int (age) >= 18:# Введите условие для проверки возраста
        result = 'Доступ разрешён'
    else:
        result = 'Доступ запрещён'
except ValueError:
    print("Ошибка: нужно ввести число!")
print (result)
# Out:
# Введите Ваш возраст hj
# Ошибка: нужно ввести число!
# Доступ запрещён

# %% [markdown]
# ### Задание 4
#
# Велопрогулка (задание из "тренажера")
#
# Вы решаете, стоит ли сегодня отправиться на долгую велопрогулку. Чтобы поездка была комфортной и безопасной, ваш велосипед должен быть полностью исправен.
# Исправность велосипеда задаётся переменной is_bike_ok. Значение True означает, что велосипед исправен, а значение False — неисправен.
#
# Напишите программу, которая поможет принять решение на основе состояния велосипеда. Если велосипед исправен, программа должна вывести ответ: «Можно кататься». Если же велосипед неисправен, программа должна вывести ответ: «Почините велосипед».

# %%
is_bike_ok = True
def bike_ride(is_bike_ok):
    # Впишите код в пропуски ниже вместо многоточия
    if is_bike_ok == True:
        result = 'Можно кататься'
    else:
        result = 'Почините велосипед'
    
    print(result) # раскомментируйте эту строку, если хотите проверить результат вашего кода
    return result # этот код менять не нужно

# попробуйте менять значения переменной is_bike_ok 
# варианты значений и результат, который вы должны увидеть:
# True - сообщение 'Можно кататься'
# False - сообщение 'Почините велосипед'

# %% [markdown]
# ### Задание 5
#
# ### Проверка логина и пароля
#
# Допишите программу, которая проверяет логин (переменная login) и пароль (переменная password) пользователя. Если логин равен 'admin' и пароль равен 'password', программа должна выводить сообщение «Добро пожаловать», иначе — сообщение «Доступ ограничен».
#
# Обратите внимание: кавычки в ответе выводить не нужно!

# %%
# впишите свой код внутри этой функции
def check_auth(login: str, password: str):
    if login == 'admin' and password == 'password': # Здесь напишите свой код для проверки условия
        result = 'Добро пожаловать' # Не меняйте этот код
    else: 
        result = 'Доступ ограничен' # Не меняйте этот код
    
    # print(result) # раскомментируйте эту строку, если хотите проверить  результат вашего кода
    return result # не изменяйте этот код

# варианты пар логин-пароль и результат, который вы должны увидеть:
# 'admin', 'password' - сообщение 'Верные login, password: Добро пожаловать'
# 'user', 'password' - сообщение 'Неверный login: Доступ ограничен'
# 'admin', '123' - сообщение 'Неверный password: Доступ ограничен'

login = 'admin' # здесь вы можете менять логин
password = 'password' # здесь вы можете менять пароль
